# %%
# Cài đặt các gói cần thiết
# !pip install pyngrok
# !apt-get update && apt-get install -y openssh-server
# !echo 'root:123456' | chpasswd

# !sed -i 's/#PermitRootLogin prohibit-password/PermitRootLogin yes/' /etc/ssh/sshd_config
# !sed -i 's/PasswordAuthentication no/PasswordAuthentication yes/' /etc/ssh/sshd_config

# !service ssh start

import os
from pyngrok import ngrok
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
ngrok_token = user_secrets.get_secret("ngrok_token")
# # Lấy token từ Kaggle Secrets

# Kết nối ngrok
ngrok.set_auth_token(ngrok_token)
ssh_tunnel = ngrok.connect(22, "tcp")
print("SSH Tunnel đã sẵn sàng! Dùng lệnh sau để kết nối:")
print(f"ssh root@{ssh_tunnel.public_url.replace('tcp://', '')} -p {ssh_tunnel.public_url.split(':')[-1]}")

# %%
# %%writefile /kaggle/working/readme.md
# ```
# import os
# os.environ["PATH"] += os.pathsep + "/opt/bin"
# !nvidia-smi
# ```
# ```
# echo "/usr/local/nvidia/lib64" | sudo tee /etc/ld.so.conf.d/nvidia.conf
# ldconfig
# source /opt/conda/etc/profile.d/conda.sh
# ```
# ```
# echo "/usr/local/nvidia/lib64" | sudo tee /etc/ld.so.conf.d/nvidia.conf
# ldconfig
# source /opt/conda/etc/profile.d/conda.sh
# ```

# %%
# %%writefile setup_nvidia.sh
# #!/bin/bash
#
#
# echo "/usr/local/nvidia/lib64" | sudo tee /etc/ld.so.conf.d/nvidia.conf
# ldconfig
# source /opt/conda/etc/profile.d/conda.sh
# conda activate base
#
# export PATH="/opt/bin:$PATH"
# # Thêm thư viện NVIDIA vào LD_LIBRARY_PATH
# export LD_LIBRARY_PATH=/usr/local/nvidia/lib64:$LD_LIBRARY_PATH
#
# # In ra LD_LIBRARY_PATH để kiểm tra
# echo "LD_LIBRARY_PATH hiện tại: $LD_LIBRARY_PATH"

# %%
# %%writefile setup_uv.sh
# uv add transformers datasets torch
# uv add git+https://github.com/huggingface/accelerate
# # !uv add dgl==2.0.0 -f https://data.dgl.ai/wheels/cu121/repo.html
# uv add dgl==1.1.2
# uv add "numpy<2"
# uv add matplotlib
# uv add wrapt

# %%
# %%writefile setup_git.sh
# git config --global user.email "pnthangkth@gmail.com"
# git config --global user.name "thangkh02"

# %%
print("chmod +x working/setup_nvidia.sh && working/setup_nvidia.sh")

# %%
# print("use conda:")
# print(
# f"""echo "/usr/local/nvidia/lib64" | sudo tee /etc/ld.so.conf.d/nvidia.conf
# ldconfig
# source /opt/conda/etc/profile.d/conda.sh
# conda activate base
# -----------------------------------------------------------------------------------
# """)

# %%
# print("use gpu:")
# print(
# f"""export PATH="/opt/bin:$PATH"
# # Thêm thư viện NVIDIA vào LD_LIBRARY_PATH
# export LD_LIBRARY_PATH=/usr/local/nvidia/lib64:$LD_LIBRARY_PATH

# # In ra LD_LIBRARY_PATH để kiểm tra
# echo "LD_LIBRARY_PATH hiện tại: $LD_LIBRARY_PATH"
# -------------------------------------------------------------------------
# """)

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# !export PATH="$HOME/.local/bin:$PATH"

# %%
import time
time.sleep(11*3600 + 1800)

# %% [markdown]
# ```
# import os
# os.environ["PATH"] += os.pathsep + "/opt/bin"
# !nvidia-smi
# ```

# %% [markdown]
# ```
# echo "/usr/local/nvidia/lib64" | sudo tee /etc/ld.so.conf.d/nvidia.conf
# ldconfig
# source /opt/conda/etc/profile.d/conda.sh
# ```

# %% [markdown]
# ```
# pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# ```
